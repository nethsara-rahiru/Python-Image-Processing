# %%
name = 'Nancy'
age = 25
height = 4.6
is_healthy = True

# %%
print(name)
print(type(height))
# Out:
# Nancy
# <class 'float'>

# %%
#Basic Operators
num1 = 10
num2 = 4

print(num1 + num2)
print(num1 - num2)
print(num1 * num2)
print(num1 / num2)
print(num1 // num2)
print(num1 % num2)
print(num1 ** num2)
# Out:
# 14
# 6
# 40
# 2.5
# 2
# 2
# 10000

# %%
#List
list = [10, 50, 120, 200, 255]
print(list[-2])
print(list)
print(type(list))
print(list[2:4])
# Out:
# 200
# [10, 50, 120, 200, 255]
# <class 'list'>
# [120, 200]

# %%
print(min(list))
print(max(list))
print(sum(list))
# Out:
# 10
# 255
# 635

# %%
list = [10, 50, 120, 200, 255]

print(list)
list.pop()
print(list)
list.reverse()
print(list)
list.sort()
print(list)
# Out:
# [10, 50, 120, 200, 255]
# [10, 50, 120, 200]
# [200, 120, 50, 10]
# [10, 50, 120, 200]

# %%
print(len(list))
# Out:
# 4

# %%
list.append(315)
list.insert(3,180)
print(list)
# Out:
# [10, 50, 120, 180, 200, 255, 315, 315]

# %%
 #Tuple

tuple = (256,256)
print(tuple[0], tuple[0])
# Out:
# 256 256

# %%
#Dictionaries

image = {"width":256, "height":256, "channels":3}
print(image["channels"])
print(image["width"])
# Out:
# 3
# 256

# %%
#Conditionals
image = 130

if image > 200:
    print("HIGH")
elif image > 100:
    print("MEDIUM")
else:
    print(LOW)
# Out:
# MEDIUM

# %%
# FOR LOOP

for i in list:
    print(i)
# Out:
# 10
# 50
# 120
# 200

# %%
for i in range(5):
    print("Index : ", i)
# Out:
# Index :  0
# Index :  1
# Index :  2
# Index :  3
# Index :  4

# %%
# While

count = 0
while count < 3:
    print("Count is", count)
    count = count + 1
# Out:
# Count is 0
# Count is 1
# Count is 2

# %%
#funtion

def brighten(value, amount):
    new_value = value + amount
    if new_value > 255:
        new_value = 255
    return new_value

print(brighten(200, 100))
print(brighten(100, 50))
# Out:
# 255
# 150
