# %%
pixel1 = 45
pixel2 = 180
pixel3 = 255

pixels = [10, 90, 130, 200, 255, 5]
print(pixels[0])
print(pixels[-1])
middle = len(pixels)//2
print(pixels[(middle - 1):(middle + 1)])

print(max(pixels))
print(min(pixels))
print(sum(pixels)/len(pixels))
s
pixel_value = 75
if pixel_value < 50:
    print("Dark")
elif pixel_value < 150:
    print("Medium")
else:
    print("Bright")
    
for i in pixels:
    pixel_value = i
    if pixel_value < 50:
        print("Dark")
    elif pixel_value < 150:
        print("Medium")
    else:
        print("Bright")
# Out:
# 10
# 5
# [130, 200]
# 255
# 5
# 115.0
# Medium
# Dark
# Medium
# Medium
# Bright
# Bright
# Dark
